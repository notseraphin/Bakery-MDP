# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.markov import InventoryMDP
from src.analysis import *

# %%
mdp = InventoryMDP(max_inventory=10, max_order=5)

# %%
V, policy = mdp.value_iteration()
print("Optimal Policy:", policy)

# %%
plot_policy(policy)

# %%
dist = mdp.steady_state_distribution(policy)
print("Steady-state distribution:", dist)

# %%
plot_steady_state(dist)
